# %% [markdown]
# # Pandas GroupBy

# %%
import pandas as pd

# %%
df = pd.read_csv("DataSets/Employee.csv")
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier   Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3  34.0    Male          No
# 1  Bachelors         2013       Pune            1  28.0  Female          No
# 2  Bachelors         2014  New Delhi            3  38.0  Female          No
# 3    Masters         2016  Bangalore            3  27.0    Male          No
# 4    Masters         2017       Pune            3  24.0    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
grouped = df.groupby("Education")
# print(grouped.size())
# print(grouped.count())
# print(grouped.describe())
# print(grouped.LeaveOrNot.mean())
# print(grouped.Age.max())
# print(grouped.get_group("Masters").min())
print(grouped.City.min())
# Out:
# Education
# Bachelors    Bangalore
# Masters      Bangalore
# PHD          Bangalore
# Name: City, dtype: object

# %%
grouped = df.groupby("City")

# %%
for grouped_name, grouped_df in grouped:
    print(grouped_name)
    print(grouped_df)
# Out:
# Bangalore
#       Education  JoiningYear       City  PaymentTier   Age  Gender  \
# 0     Bachelors         2017  Bangalore            3  34.0    Male
# 3       Masters         2016  Bangalore            3  27.0    Male
# 5     Bachelors         2016  Bangalore            3  22.0    Male
# 7     Bachelors         2016  Bangalore            3  34.0  Female
# 10      Masters         2012  Bangalore            3  27.0    Male
# ...         ...          ...        ...          ...   ...     ...
# 4643  Bachelors         2013  Bangalore            3  31.0  Female
# 4646  Bachelors         2013  Bangalore            3  25.0  Female
# 4648  Bachelors         2013  Bangalore            3  26.0  Female
# 4651  Bachelors         2012  Bangalore            3  30.0    Male
# 4652  Bachelors         2015  Bangalore            3  33.0    Male
#
#      EverBenched  ExperienceInCurrentDomain  LeaveOrNot
# 0             No                          0           0
# ...

# %%
print(grouped.get_group("Pune"))
# Out:
#       Education  JoiningYear  City  PaymentTier   Age  Gender EverBenched  \
# 1     Bachelors         2013  Pune            1  28.0  Female          No
# 4       Masters         2017  Pune            3  24.0    Male         Yes
# 8     Bachelors         2016  Pune            3  23.0    Male          No
# 11    Bachelors         2016  Pune            3  34.0    Male          No
# 12    Bachelors         2018  Pune            3  32.0    Male         Yes
# ...         ...          ...   ...          ...   ...     ...         ...
# 4630  Bachelors         2012  Pune            3  25.0  Female          No
# 4644  Bachelors         2015  Pune            3  32.0  Female         Yes
# 4645    Masters         2017  Pune            2  31.0  Female          No
# 4647  Bachelors         2016  Pune            3  30.0    Male          No
# 4649    Masters         2013  Pune            2  37.0    Male          No
#
#       ExperienceInCurrentDomain  LeaveOrNot
# ...

# %%
grouped.describe()
# Out:
#           JoiningYear                                                         \
#                 count         mean       std     min     25%     50%     75%
# City
# Bangalore      2228.0  2014.859515  1.899711  2012.0  2013.0  2015.0  2017.0
# New Delhi      1157.0  2015.522040  1.862182  2012.0  2014.0  2016.0  2017.0
# Pune           1268.0  2015.001577  1.724057  2012.0  2014.0  2015.0  2017.0
#
#                   PaymentTier            ... ExperienceInCurrentDomain       \
#               max       count      mean  ...                       75%  max
# City                                     ...
# Bangalore  2018.0      2228.0  2.870287  ...                       4.0  7.0
# New Delhi  2018.0      1157.0  2.598099  ...                       4.0  6.0
# Pune       2018.0      1268.0  2.487382  ...                       4.0  7.0
#
#           LeaveOrNot
#                count      mean       std  min  25%  50%  75%  max
# City
# ...
