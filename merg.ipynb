# %%
import pandas as pd

# %%
df1 = pd.read_csv("DataSets/Titanic-Dataset.csv")

# %%
df2 = pd.read_csv("DataSets/Employee.csv")

# %%
df1.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df2.head(2)
# Out:
#    Education  JoiningYear       City  PaymentTier   Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3  34.0    Male          No
# 1  Bachelors         2013       Pune            1  28.0  Female          No
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1

# %%
pd.merge(df1, df2, on="Age")
# Out:
#        PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 0                1         0       3  Braund, Mr. Owen Harris  male  22.0
# 1                1         0       3  Braund, Mr. Owen Harris  male  22.0
# 2                1         0       3  Braund, Mr. Owen Harris  male  22.0
# 3                1         0       3  Braund, Mr. Owen Harris  male  22.0
# 4                1         0       3  Braund, Mr. Owen Harris  male  22.0
# ...            ...       ...     ...                      ...   ...   ...
# 92455          891         0       3      Dooley, Mr. Patrick  male  32.0
# 92456          891         0       3      Dooley, Mr. Patrick  male  32.0
# 92457          891         0       3      Dooley, Mr. Patrick  male  32.0
# 92458          891         0       3      Dooley, Mr. Patrick  male  32.0
# 92459          891         0       3      Dooley, Mr. Patrick  male  32.0
#
#        SibSp  Parch     Ticket  Fare Cabin Embarked  Education  JoiningYear  \
# ...

# %%
pd.merge(df1, df2, on="Age", how='inner')
# Out:
#        PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 0                1         0       3  Braund, Mr. Owen Harris  male  22.0
# 1                1         0       3  Braund, Mr. Owen Harris  male  22.0
# 2                1         0       3  Braund, Mr. Owen Harris  male  22.0
# 3                1         0       3  Braund, Mr. Owen Harris  male  22.0
# 4                1         0       3  Braund, Mr. Owen Harris  male  22.0
# ...            ...       ...     ...                      ...   ...   ...
# 92455          891         0       3      Dooley, Mr. Patrick  male  32.0
# 92456          891         0       3      Dooley, Mr. Patrick  male  32.0
# 92457          891         0       3      Dooley, Mr. Patrick  male  32.0
# 92458          891         0       3      Dooley, Mr. Patrick  male  32.0
# 92459          891         0       3      Dooley, Mr. Patrick  male  32.0
#
#        SibSp  Parch     Ticket  Fare Cabin Embarked  Education  JoiningYear  \
# ...

# %%
pd.merge(df1, df2, on="Age", how='left')
# Out:
#        PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 0                1         0       3  Braund, Mr. Owen Harris  male  22.0
# 1                1         0       3  Braund, Mr. Owen Harris  male  22.0
# 2                1         0       3  Braund, Mr. Owen Harris  male  22.0
# 3                1         0       3  Braund, Mr. Owen Harris  male  22.0
# 4                1         0       3  Braund, Mr. Owen Harris  male  22.0
# ...            ...       ...     ...                      ...   ...   ...
# 92813          891         0       3      Dooley, Mr. Patrick  male  32.0
# 92814          891         0       3      Dooley, Mr. Patrick  male  32.0
# 92815          891         0       3      Dooley, Mr. Patrick  male  32.0
# 92816          891         0       3      Dooley, Mr. Patrick  male  32.0
# 92817          891         0       3      Dooley, Mr. Patrick  male  32.0
#
#        SibSp  Parch     Ticket  Fare Cabin Embarked  Education  JoiningYear  \
# ...

# %%
pd.merge(df1, df2, on="Age", how='right')
# Out:
#        PassengerId  Survived  Pclass  \
# 0               22         1       2
# 1               99         1       2
# 2              100         0       2
# 3              203         0       3
# 4              406         0       2
# ...            ...       ...     ...
# 92455          753         0       3
# 92456          760         1       1
# 92457          810         1       1
# 92458          873         0       1
# 92459          882         0       3
#
#                                                     Name     Sex   Age  SibSp  \
# 0                                  Beesley, Mr. Lawrence    male  34.0      0
# 1                   Doling, Mrs. John T (Ada Julia Bone)  female  34.0      0
# 2                                      Kantor, Mr. Sinai    male  34.0      1
# 3                             Johanson, Mr. Jakob Alfred    male  34.0      0
# 4                                     Gale, Mr. Shadrach    male  34.0      1
# ...

# %%
pd.merge(df1, df2, on="Age", how='outer')
# Out:
#        PassengerId  Survived  Pclass  \
# 0              804         1       3
# 1              756         1       2
# 2              470         1       3
# 3              645         1       3
# 4               79         1       2
# ...            ...       ...     ...
# 92813          879         0       3
# 92814          879         0       3
# 92815          889         0       3
# 92816          889         0       3
# 92817          889         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0               Thomas, Master. Assad Alexander    male  0.42      0      1
# 1                     Hamalainen, Master. Viljo    male  0.67      1      1
# 2                 Baclini, Miss. Helene Barbara  female  0.75      2      1
# 3                        Baclini, Miss. Eugenie  female  0.75      2      1
# 4                 Caldwell, Master. Alden Gates    male  0.83      0      2
# ...

# %%
pd.concat([df1, df2], axis=1)
# Out:
#       PassengerId  Survived  Pclass  \
# 0             1.0       0.0     3.0
# 1             2.0       1.0     1.0
# 2             3.0       1.0     3.0
# 3             4.0       1.0     1.0
# 4             5.0       0.0     3.0
# ...           ...       ...     ...
# 4648          NaN       NaN     NaN
# 4649          NaN       NaN     NaN
# 4650          NaN       NaN     NaN
# 4651          NaN       NaN     NaN
# 4652          NaN       NaN     NaN
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0    1.0
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                                Heikkinen, Miss. Laina  female  26.0    0.0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                              Allen, Mr. William Henry    male  35.0    0.0
# ...
